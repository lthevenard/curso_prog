# %%
import pandas as pd

# %%
cartoes = pd.read_csv("../data/dados_cartoes.csv")

# %%
cartoes
# Out:
#          data_pgto   ano  mes forma_pagamento     valor  \
# 0       2003-01-02  2003    1          Débito   1696.90
# 1       2003-01-02  2003    1          Débito   1336.60
# 2       2003-01-02  2003    1          Débito   1396.43
# 3       2003-01-03  2003    1          Débito    105.00
# 4       2003-01-03  2003    1          Débito    200.00
# ...            ...   ...  ...             ...       ...
# 114958  2022-12-29  2022   12         Crédito    210.80
# 114959  2022-12-29  2022   12         Crédito    536.13
# 114960  2022-12-29  2022   12         Crédito    673.82
# 114961  2022-12-29  2022   12         Crédito   2147.53
# 114962  2022-12-31  2022   12         Crédito  36327.36
#
#                                       tipo_despesa  \
# 0                   LOCACAO DE MEIOS DE TRANSPORTE
# 1                   LOCACAO DE MEIOS DE TRANSPORTE
# 2                   LOCACAO DE MEIOS DE TRANSPORTE
# 3             MATERIAL P/MANUTENÇÃO DE BENS MÓVEIS
# ...
